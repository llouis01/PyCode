# %%
# !pip install pdfminer
# Out:
# ...
#   Created wheel for pdfminer: filename=pdfminer-20191125-py3-none-any.whl size=6140131 sha256=42f35b1a55d9cc077642086a0e8cfaa504df646351477539484fd6017f0c7453
#   Stored in directory: c:\users\loube\appdata\local\pip\cache\wheels\1c\28\7d\f390b82bb0307deb63ff27a1474fd308ec68ee028cb9ab6283
# Successfully built pdfminer
# ...

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
