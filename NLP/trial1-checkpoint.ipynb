# %%
import pandas as pd

# %%
data = pd.read_excel("C:\\Users\\Loube\\Documents\\GitHub\\Python_Codes\\NLP\\comments.xlsx")

# %%
data
# Out:
#      Talker                                            Comment
# 0    index1  "I don't think TikTok is good for our kids. To...
# 1    index2                             Tiktok is the future."
# 2    index3  "I use TikTok everyday, but I know it can caus...
# 3    index4  "Social media as a whole is very dangerous. In...
# 4    index5  "I don't use Tiktok. I THINK the content creat...
# 5    index6  "I like Tiktok, it's very hi and creative. Old...
# 6    index7  "My sister uses Tiktok everyday, and she has s...
# 7    index8     "I don't use tiktok, but I'll try it one day."
# 8    index9              "Tiktok is just snapchat on steroids"
# 9   index10  "Tiktok is very dangerous with these dangerous...
# 10  index11  "I have instagram, and I think that's ok. I ge...
# 11  index12  "China is a very oppressive country, with no i...
